# %%
1+1
# Out:
# 2

# %%
5+5
# Out:
# 10

# %%
a = 10

# %%
a
# Out:
# 10

# %%
mas = 23

# %%
mas + a
# Out:
# 33

# %%
mas + 3
# Out:
# 26

# %%
type(mas)
# Out:
# int

# %%
b = 45.00

# %%
type(b)
# Out:
# float

# %%
c = "muzammil"

# %%
type(c)
# Out:
# str

# %%
d = "this is my first tech class"

# %%
type(d)
# Out:
# str

# %%
v = 4 + 5j

# %%
type(v)
# Out:
# complex

# %%
v.imag
# Out:
# 5.0

# %%
v.real
# Out:
# 4.0

# %%
v.conjugate
# Out:
# <function complex.conjugate()>

# %%
print("my name is muzammil")
# Out:
# my name is muzammil

# %%
print(a)
# Out:
# 10

# %%
print(d)
# Out:
# this is my first tech class

# %%
s = "muzammil"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'm'

# %%
s[0:5]
# Out:
# 'muzam'

# %%
s[7]
# Out:
# 'l'

# %%
s[-1]
# Out:
# 'l'

# %%
s[0:8]
# Out:
# 'muzammil'

# %%
s[0:8:2]
# Out:
# 'mzmi'

# %%
s[0:9:2]
# Out:
# 'mzmi'

# %%
s[::2]
# Out:
# 'mzmi'

# %%
s[2::2]
# Out:
# 'zmi'

# %%
s[::-1]
# Out:
# 'limmazum'

# %%
s[-1:-9:-1]
# Out:
# 'limmazum'

# %%
s[::]
# Out:
# 'muzammil'

# %%
s[::-1]
# Out:
# 'limmazum'

# %%
s[:-90:1]
# Out:
# ''

# %%
s[:-90:-1]
# Out:
# 'limmazum'

# %%
s[:-90000:-1]
# Out:
# 'limmazum'

# %%
s1 = "this is my string"

# %%
len(s1)
# Out:
# 17

# %%
s1.find('h')
# Out:
# 1

# %%
s1.find('i')
# Out:
# 2

# %%
s1.find('m')
# Out:
# 8

# %%
s1.find('n')
# Out:
# 15

# %%
s1
# Out:
# 'this is my string'

# %%
s1.count('t')
# Out:
# 2

# %%
s1.count('my')
# Out:
# 1

# %%
s1.count('string')
# Out:
# 1

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING'

# %%
s1.lower()
# Out:
# 'this is my string'

# %%
s1.title()
# Out:
# 'This Is My String'

# %%
s1.capitalize()
# Out:
# 'This is my string'

# %%
s1
# Out:
# 'this is my string'

# %%
s1 + " and concatination"
# Out:
# 'this is my string and concatination'

# %%
s1 + " 234"
# Out:
# 'this is my string 234'

# %%
s2 = "ms"

# %%
s2 * 3
# Out:
# 'msmsms'

# %%
s2 * 2
# Out:
# 'msms'

# %%
s2 * 5
# Out:
# 'msmsmsmsms'

# %%
s2 * 100
# Out:
# 'msmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsmsms'
