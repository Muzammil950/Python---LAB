# %%
class pwskills:

    def __init__(self, name, email):

        self.name = name
        self.email = email

    def students_details(self):
        print(self.name, self.email)

# %%
pw = pwskills("rohan", "rohan@gmail.com")

# %%
pw.name
# Out:
# 'rohan'

# %%
pw.email
# Out:
# 'rohan@gmail.com'

# %%
pw.students_details()
# Out:
# rohan rohan@gmail.com

# %%
class pwskills1:

    def __init__ (self, name, email):
        self.name = name
        self.email = email

    @classmethod
    def details(cls, name, email):
        return cls(name, email)
    

    def students_details(self):
        return self.name, self.email

# %%
pw1 = pwskills1.details("sohan","sohan@gmail.com")

# %%
pw1.name
# Out:
# 'sohan'

# %%
pw1.email
# Out:
# 'sohan@gmail.com'

# %%
class pwskills2:

    mobile_num = 99999999

    def __init__(self, name, email):
        self.name = name
        self.email = email


    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_num = mobile
    
    @classmethod
    def details(cls, name, email):
        return cls(name, email)

    def students_details(self):
        print( self.name, self.email, pwskills2.mobile_num)

# %%
pw_obj = pwskills2("muzz","muzz@gmail.com")

# %%
pw_obj.students_details()
# Out:
# muzz muzz@gmail.com 99999999

# %%
pw = pwskills2.details("johan", "johan@gmail.com")

# %%
pw.students_details()
# Out:
# johan johan@gmail.com 99999999

# %%
pwskills2.change_number(88888888)

# %%
pwskills2.mobile_num
# Out:
# 88888888

# %%
def course_details(cls, course_name):
    print("course name is ", course_name)

# %%
pwskills2.course_details = classmethod(course_details)

# %%
pwskills2.course_details("data science")
# Out:
# course name is  data science

# %%
def mentor(cls, list_of_mentor):
    print(list_of_mentor)

# %%
pwskills2.mentor =  classmethod(mentor)

# %%
pwskills2.mentor(['saktiman','krish'])
# Out:
# ['saktiman', 'krish']

# %%
class pwskills3:

    mobile_num = 99999999

    def __init__(self, name, email):
        self.name = name
        self.email = email


    @classmethod
    def change_number(cls, mobile):
        pwskills2.mobile_num = mobile
    
    @classmethod
    def details(cls, name, email):
        return cls(name, email)

    def students_details(self):
        print( self.name, self.email, pwskills2.mobile_num)

# %%
pwskills3.
# Out:
#   Cell In[59], line 1
#     pwskills3.
#               ^
# SyntaxError: invalid syntax

# %%
del pwskills3.change_number # delete method of change_number

# %%
pwskills3.

# %%
delattr(pwskills3 , "details") # delete method of details

# %%
pwskills3.
