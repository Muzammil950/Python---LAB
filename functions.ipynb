# %%
print("its print func")
# Out:
# its print func

# %%
l = [1,2,3]

# %%
len(l)
# Out:
# 3

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
def test1():
    print("this is my first function")

# %%
test1()
# Out:
# this is my first function

# %%
def test1():
    return "this is my first return"

# %%
test1() + " func"
# Out:
# 'this is my first return func'

# %%
def test2():
    return "muzz", 23, 2.22, [1,2,3]

# %%
test2()
# Out:
# ('muzz', 23, 2.22, [1, 2, 3])

# %%
a,b,c,d = test2()

# %%
a
# Out:
# 'muzz'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 2.22

# %%
d
# Out:
# [1, 2, 3]

# %%
def test3():
    a = 5+6/7
    return a

# %%
test3()
# Out:
# 5.857142857142857

# %%
def test4(a,b,c):
    d = a+b/c
    return d

# %%
test4(5,6,7)
# Out:
# 5.857142857142857

# %%
def test5(a,b):
    return a + b

# %%
test5(2,3)
# Out:
# 5

# %%
test5('abc',' def')
# Out:
# 'abc def'

# %%
test5([1,2,3],[4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l = [1,2,3,4, 'small', 'big', [6,7,0,8,9]]

# %%
l1 =[]
for i in l:
    if type(i) == int ort type(i) == float:
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test6(l):
    l1 = []
    for i in l:
        if type(i) == int or type(i) == float:
            l1.append(i)
    return l1

# %%
test6(l)
# Out:
# [1, 2, 3, 4]

# %%
def test7(a):
    l2 = []
    for i in a :
        if type(i) == list:
            for j in i :
                l2.append(j)
        else:
            if type(i) == int or type(i) == float:
                l2.append(i)
    return l2

# %%
test7(l)
# Out:
# [1, 2, 3, 4, 6, 7, 0, 8, 9]

# %%
def test7(a):
    """this is my function"""
    l2 = []
    for i in a:
        if type(i) == list:
            for j in i:
                l2.append(j)
        else:
            if type(i) == int or type(i) == float:
                l2.append(i)
    return l2

# %%
test7(l)
# Out:
# [1, 2, 3, 4, 6, 7, 0, 8, 9]

# %%
def test8(a,b):
    return a+b

# %%
test8(2,4)
# Out:
# 6

# %%
def test9(*args):
    return args

# %%
test9(1,2)
# Out:
# (1, 2)

# %%
test9(1,2,3,'harry','parry',[1,2,3,4])
# Out:
# (1, 2, 3, 'harry', 'parry', [1, 2, 3, 4])

# %%
def test9(*muzz):
    return muzz

# %%
test9('a','b',12,44,[2,3,4])
# Out:
# ('a', 'b', 12, 44, [2, 3, 4])

# %%
def test10(*args, a):
    return args, a

# %%
test10(1,2,3,4,  a = 22)
# Out:
# ((1, 2, 3, 4), 22)

# %%
def test11(c,d, a = 1, b = 2):
    return a,b,c,d

# %%
test11(3,4)
# Out:
# (1, 2, 3, 4)

# %%
def test11(c,d, a=1,b=2):
    return d,c,b,a

# %%
test11(3,4)
# Out:
# (4, 3, 2, 1)

# %%
def test12(**kwargs):
    return kwargs

# %%
test12()
# Out:
# {}

# %%
test12(a = [1,2,3,4], b = 'muzz', c = 23.4)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'muzz', 'c': 23.4}
