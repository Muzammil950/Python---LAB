# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {"key" : "value"}
d1
# Out:
# {'key': 'value'}

# %%
d2 = {"name" : "arman", "email" : "arman@gmail.com", "num" : 9898980998, True : "ok", False : "not ok"}

# %%
d2
# Out:
# {'name': 'arman',
#  'email': 'arman@gmail.com',
#  'num': 9898980998,
#  True: 'ok',
#  False: 'not ok'}

# %%
d2["name"]
# Out:
# 'arman'

# %%
d2['email']
# Out:
# 'arman@gmail.com'

# %%
d2['num']
# Out:
# 9898980998

# %%
d2[1]
# Out:
# 'ok'

# %%
d2[0]
# Out:
# 'not ok'

# %%
d4 = {'name' : "asif", 'email' : "asif@gmail.com", 'name' : "arif"}
d4
# Out:
# {'name': 'arif', 'email': 'asif@gmail.com'}

# %%
d4['name']
# Out:
# 'arif'

# %%
d5 = {"company" : "[pwskills", "course" : ["data science", "web dev", "clauds engg"]}
d5
# Out:
# {'company': '[pwskills', 'course': ['data science', 'web dev', 'clauds engg']}

# %%
d5["course"]
# Out:
# ['data science', 'web dev', 'clauds engg']

# %%
d5['course'][1]
# Out:
# 'web dev'

# %%
d5['course'][2]
# Out:
# 'clauds engg'
