# %%
from functools import reduce

# %%
l = [1,2,3,4,5]

# %%
reduce(lambda x,y : x+y, l)
# Out:
# 15

# %%
reduce(lambda x,y : x*y , l)
# Out:
# 120

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
reduce(lambda x,y : x if x>y else y, l)
# Out:
# 5

# %% [markdown]
# # Filter

# %%
l = [1,2,2,3,3,4,5,6,7,8,]

# %%
list(filter(lambda x : x % 2 == 0, l))
# Out:
# [2, 2, 4, 6, 8]

# %%
list(filter(lambda x : x % 2 != 0, l))
# Out:
# [1, 3, 3, 5, 7]

# %%
l1 = [1,2,-8,6,-3,-7,8,7,-9,5,-4]

# %%
list(filter(lambda x : x < 0, l1))
# Out:
# [-8, -3, -7, -9, -4]

# %%
l2 = ['arif', 'asif', 'anhaan', 'dance', 'he dances']

# %%
list(filter(lambda x : len(x) < 5, l2))
# Out:
# ['arif', 'asif']
