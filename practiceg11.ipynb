# %%
class pwskills:

    def welcome_msg(self):
        print("welcome to pwskills")

# %%
rohan = pwskills()

# %%
rohan.welcome_msg()
# Out:
# welcome to pwskills

# %%
class edureka :

    def login_enter(access):
        print("login to site")

# %%
bablu = edureka()

# %%
bablu.login_enter()
# Out:
# login to site

# %%
class forest:

    def power(term):
        print("found")

# %%
tiger = forest()

# %%
tiger.power()
# Out:
# found
