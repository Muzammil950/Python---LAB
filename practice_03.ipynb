# %%
def test():
   a =4+5/6
   return a

# %%
test()
# Out:
# 4.833333333333333

# %%
def test1(a,b,c):
    d = a+b/c
    return d

# %%
test1(4,5,6)
# Out:
# 4.833333333333333

# %%
l = [1,2,3,4,'sum','add',[1,3,4,55,22,5,5]]

# %%
def test2(a):
    l2 = []
    for i in l:
        if type(i) == list:
            for j in i:
                l2.append(j)
    return l2

# %%
test2(l)
# Out:
# [1, 3, 4, 55, 22, 5, 5]

# %%
a = lambda x: x**2

# %%
a(2)
# Out:
# 4

# %%
b = lambda x,y : x**y

# %%
b(2,3)
# Out:
# 8

# %%
add = lambda x,y : x+y

# %%
add(2,4)
# Out:
# 6

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(4,3)
# Out:
# 4

# %%
find_len = lambda x : len(x)

# %%
find_len('hhhkffh')
# Out:
# 7
