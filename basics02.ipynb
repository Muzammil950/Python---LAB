# %%
l = [23, 234, True, 4+5j, 34.4, "Muzz"]

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 23

# %%
l[3]
# Out:
# (4+5j)

# %%
l[5]
# Out:
# 'Muzz'

# %%
l
# Out:
# [23, 234, True, (4+5j), 34.4, 'Muzz']

# %%
l[0:3]
# Out:
# [23, 234, True]

# %%
l[-1]
# Out:
# 'Muzz'

# %%
l[::-1]
# Out:
# ['Muzz', 34.4, (4+5j), True, 234, 23]

# %%
l[::2]
# Out:
# [23, True, 34.4]

# %%
l[2]
# Out:
# True

# %%
str(l[2])[0:3]
# Out:
# 'Tru'

# %%
l1 = [2,3,4]

# %%
l1 + l
# Out:
# [2, 3, 4, 23, 234, True, (4+5j), 34.4, 'Muzz']

# %%
l1 * 3
# Out:
# [2, 3, 4, 2, 3, 4, 2, 3, 4]

# %%
len(l)
# Out:
# 6

# %%
l.append(23)

# %%
l
# Out:
# [23, 234, True, (4+5j), 34.4, 'Muzz', 23]

# %%
l.extend("jaduuu")

# %%
l
# Out:
# [23, 234, True, (4+5j), 34.4, 'Muzz', 23, 'j', 'a', 'd', 'u', 'u', 'u']

# %%
l.extend(34)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 l.extend(34)
#
# TypeError: 'int' object is not iterable

# %%
l.extend([9,8,7])

# %%
l
# Out:
# [23,
#  234,
#  True,
#  (4+5j),
#  34.4,
#  'Muzz',
#  23,
#  'j',
#  'a',
#  'd',
#  'u',
#  'u',
#  'u',
#  9,
#  8,
#  7]

# %%
l1
# Out:
# [2, 3, 4]

# %%
l1.insert(1, 34)

# %%
l1
# Out:
# [2, 34, 3, 4]

# %%
l1.insert(3, [4,5,7])

# %%
l1
# Out:
# [2, 34, 3, [4, 5, 7], 4]

# %%
l1.insert(-1, 44)

# %%
l1
# Out:
# [2, 34, 3, [4, 5, 7], 44, 4]

# %%
l1.pop()
# Out:
# 4

# %%
l1
# Out:
# [2, 34, 3, [4, 5, 7], 44]

# %%
l1.remove(34)

# %%
l1
# Out:
# [2, 3, [4, 5, 7], 44]

# %%
l1[2].remove(5)

# %%
l1
# Out:
# [2, 3, [4, 7], 44]

# %%
l2 = [89,32,2,34,56,87, 2, 5 ]

# %%
l2.sort()
l2
# Out:
# [2, 2, 5, 32, 34, 56, 87, 89]

# %%
l3 = ["b","a","f","e","d","c"]

# %%
l3.sort()
l3
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
l3.count("d")
# Out:
# 1

# %%
s = "Muzz"

# %%
s[0]
# Out:
# 'M'

# %%
s[0] = 'n'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 s[0] = 'n'
#
# TypeError: 'str' object does not support item assignment

# %%
l5 = [1,2,3,4]

# %%
l5[3] = 5
l5
# Out:
# [1, 2, 3, 5]

# %%
t = (2, 3, 4, 23, 234, True, (4+5j), 34.4, 'Muzz')

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# 'Muzz'

# %%
t[::-1]
# Out:
# ('Muzz', 34.4, (4+5j), True, 234, 23, 4, 3, 2)

# %%
t
# Out:
# (2, 3, 4, 23, 234, True, (4+5j), 34.4, 'Muzz')

# %%
t[0] = 56
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 t[0] = 56
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(4)
# Out:
# 1

# %%
t.index(True)
# Out:
# 5

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s1={2,3,5,7,3,5,4,3,2}

# %%
type(s1)
# Out:
# set

# %%
s1
# Out:
# {2, 3, 4, 5, 7}

# %%
l3
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
l3 = set(l3)
l3
# Out:
# {'a', 'b', 'c', 'd', 'e', 'f'}

# %%
l3 = list(l3)
l3
# Out:
# ['c', 'e', 'a', 'b', 'd', 'f']

# %%
s1
# Out:
# {2, 3, 4, 5, 7}

# %%
s1.add(8)
s1
# Out:
# {2, 3, 4, 5, 7, 8}
