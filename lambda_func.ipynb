# %%
n = 3
p = 2

# %%
def test(n,p):
    return n**p

# %%
test(3,2)
# Out:
# 9

# %%
a = lambda n, p : n**p

# %%
a(3,2)
# Out:
# 9

# %%
add = lambda x, y : x+y

# %%
add(2,3)
# Out:
# 5

# %%
c_to_f = lambda c : (9/5)*c + 32

# %%
c_to_f(25)
# Out:
# 77.0

# %%
finding_max = lambda x,y : x if x>y else y

# %%
finding_max(34,23)
# Out:
# 34

# %%
s = 'muzz'

# %%
length = lambda n : len(n)

# %%
length(s)
# Out:
# 4

# %%
f = 'kfjadfjklajfdla'

# %%
length(f)
# Out:
# 15
