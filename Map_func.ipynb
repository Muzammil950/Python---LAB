# %%
l = [1,2,3,4,5]

# %%
l1 = []
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 25]

# %%
def test(l):
    l1 = []
    for i in l:
        l1.append(i**2)
    return l1

# %%
test(l)
# Out:
# [1, 4, 9, 16, 25]

# %%
def sq(x):
    return x**2

# %%
sq(4)
# Out:
# 16

# %%
list(map(sq, l))
# Out:
# [1, 4, 9, 16, 25]

# %%
list(map(lambda x : x**2, l))
# Out:
# [1, 4, 9, 16, 25]

# %%
l1 =[1,2,3,4,5]
l2 = [6,7,8,9,10]

# %%
list(map(lambda x, y : x+y , l1, l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
def add (x,y) :
    return x + y

# %%
list(map(add, l1, l2))
# Out:
# [7, 9, 11, 13, 15]

# %%
s = 'abcdefghi'
list(map(lambda s : s.upper(), s))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
