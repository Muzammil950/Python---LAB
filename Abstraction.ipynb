# %%
 import abc

# %%
class pwskills:

    @abc.abstractmethod
    def students_details(self):
        pass

    @abc.abstractmethod
    def students_assignment(self):
        pass

    @abc.abstractmethod
    def students_marks(self):
        pass

# %%
class students_details(pwskills):

    def students_details(self):
        return "this is a methd of student details"

    def students_assignment(self):
        return "this is a methd of student assignment"

# %%
class data_science_master(pwskills):

    def student_details(self):
        return "this is methd of student details for data science"

    def student_assignment(self):
        return "this is methd of student details for data science"

# %%
dsm = data_science_master()

# %%
dsm.student_details()
# Out:
# 'this is methd of student details for data science'

# %%
dsm.student_assignment()
# Out:
# 'this is methd of student details for data science'

# %%
sd = students_details()

# %%
sd.students_assignment()
# Out:
# 'this is a methd of student assignment'
